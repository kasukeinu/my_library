# %%
from coordinate_transformation import *
import numpy as np
import matplotlib.pyplot as plt

# %%
'''
polar_coordinate_conversionの動作確認
'''
# 極座標に変換
tmp = np.array([1,-2,3,-4])
r,phi,theta=polar_coordinate_conversion(tmp,tmp,tmp,normalization=None)

# デカルト座標系に再変換
x_,y_,z_=resolve_polar_coordinate_conversion(r,phi,theta)

#3次元上で可視化
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
for i in zip(x_,y_,z_):
    print(i)
    ax.scatter(i[0],i[1],i[2])
# Out:
# (1.0, 0.9999999999999998, 0.9999999999999999)
# (-1.9999999999999996, -2.0, -1.9999999999999998)
# (3.0000000000000004, 3.0, 3.0000000000000004)
# (-3.999999999999999, -4.0, -3.9999999999999996)
